# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanhyuti/ET/blob/main/prac5py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Practical_5_Boston (1).csv')

# %%
numeric_cols = data.select_dtypes(include=['number']).columns

# %%
for col in numeric_cols:
    # Descriptive statistics
    print(data[col].describe())

    # Histogram
    plt.figure()
    sns.histplot(data[col])
    plt.title(f'Distribution of {col}')
    plt.show()

    # Box plot
    plt.figure()
    sns.boxplot(y=data[col])
    plt.title(f'Box Plot of {col}')
    plt.show()
# Out:
# count    506.000000
# mean     253.500000
# std      146.213884
# min        1.000000
# 25%      127.250000
# 50%      253.500000
# 75%      379.750000
# max      506.000000
# Name: Unnamed: 0, dtype: float64
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: crim, dtype: float64
# count    506.000000
# mean      11.363636
# std       23.322453
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       12.500000
# max      100.000000
# Name: zn, dtype: float64
# count    506.000000
# mean      11.136779
# std        6.860353
# min        0.460000
# 25%        5.190000
# 50%        9.690000
# 75%       18.100000
# max       27.740000
# Name: indus, dtype: float64
# count    506.000000
# mean       0.069170
# std        0.253994
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# ...
